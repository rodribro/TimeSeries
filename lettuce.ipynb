# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import torch

# %% [markdown]
# ### <b> Exploratory Data Analysis - EDA <b>

# %%
lettuce_df = pd.read_csv("trial_lettuce_dataset.csv")
lettuce_df.head(10)
# Out:
#    Plant_ID       Date  Temperature (C)  Humidity (%)  TDS Value (ppm)  \
# 0         1   8/3/2023             33.4            53              582
# 1         1   8/4/2023             33.5            53              451
# 2         1   8/5/2023             33.4            59              678
# 3         1   8/6/2023             33.4            68              420
# 4         1   8/7/2023             33.4            74              637
# 5         1   8/8/2023             32.3            77              478
# 6         1   8/9/2023             32.3            75              682
# 7         1  8/10/2023             22.7            63              576
# 8         1  8/11/2023             31.9            69              662
# 9         1  8/12/2023             30.2            59              607
#
#    pH Level  Growth Days
# 0       6.4            1
# 1       6.1            2
# 2       6.4            3
# 3       6.4            4
# 4       6.5            5
# 5       6.8            6
# 6       6.0            7
# 7       6.3            8
# 8       6.1            9
# 9       6.2           10

# %%
lettuce_df.describe()
# Out:
#           Plant_ID  Temperature (C)  Humidity (%)  TDS Value (ppm)  \
# count  3169.000000      3169.000000   3169.000000      3169.000000
# mean     35.441780        28.142222     64.873462       598.045440
# std      20.243433         4.670521      8.988985       115.713047
# min       1.000000        18.000000     50.000000       400.000000
# 25%      18.000000        23.600000     57.000000       498.000000
# 50%      35.000000        30.200000     65.000000       593.000000
# 75%      53.000000        31.500000     73.000000       699.000000
# max      70.000000        33.500000     80.000000       800.000000
#
#           pH Level  Growth Days
# count  3169.000000  3169.000000
# mean      6.399211    23.140107
# std       0.234418    13.075415
# min       6.000000     1.000000
# 25%       6.200000    12.000000
# 50%       6.400000    23.000000
# 75%       6.600000    34.000000
# max       6.800000    48.000000

# %%
lettuce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3169 entries, 0 to 3168
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plant_ID         3169 non-null   int64
#  1   Date             3169 non-null   object
#  2   Temperature (C)  3169 non-null   float64
#  3   Humidity (%)     3169 non-null   int64
#  4   TDS Value (ppm)  3169 non-null   int64
#  5   pH Level         3169 non-null   float64
#  6   Growth Days      3169 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 173.4+ KB

# %% [markdown]
# <b> Null values per column: </b>

# %%
lettuce_df.isnull().sum()
# Out:
# Plant_ID           0
# Date               0
# Temperature (C)    0
# Humidity (%)       0
# TDS Value (ppm)    0
# pH Level           0
# Growth Days        0
# dtype: int64

# %% [markdown]
# <b> Column correlation: </b>

# %%
lettuce_df['Date'] = pd.to_datetime(lettuce_df['Date']) #otherwise there's a Type Error when using .corr()
lettuce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3169 entries, 0 to 3168
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Plant_ID         3169 non-null   int64
#  1   Date             3169 non-null   datetime64[ns]
#  2   Temperature (C)  3169 non-null   float64
#  3   Humidity (%)     3169 non-null   int64
#  4   TDS Value (ppm)  3169 non-null   int64
#  5   pH Level         3169 non-null   float64
#  6   Growth Days      3169 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 173.4 KB

# %%
corr_matrix = lettuce_df.corr()
corr_matrix
# Out:
#                  Plant_ID      Date  Temperature (C)  Humidity (%)  \
# Plant_ID         1.000000 -0.005159        -0.670891     -0.031960
# Date            -0.005159  1.000000        -0.074549     -0.014531
# Temperature (C) -0.670891 -0.074549         1.000000      0.028158
# Humidity (%)    -0.031960 -0.014531         0.028158      1.000000
# TDS Value (ppm)  0.011703 -0.020667        -0.011797     -0.006148
# pH Level        -0.014827  0.003043         0.014120      0.017195
# Growth Days     -0.005229  0.999997        -0.074601     -0.014481
#
#                  TDS Value (ppm)  pH Level  Growth Days
# Plant_ID                0.011703 -0.014827    -0.005229
# Date                   -0.020667  0.003043     0.999997
# Temperature (C)        -0.011797  0.014120    -0.074601
# Humidity (%)           -0.006148  0.017195    -0.014481
# TDS Value (ppm)         1.000000 -0.014981    -0.020633
# pH Level               -0.014981  1.000000     0.003023
# Growth Days            -0.020633  0.003023     1.000000

# %% [markdown]
# Visual Representation:

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap="coolwarm", linewidths=0.5)
# Out:
# <Axes: >
