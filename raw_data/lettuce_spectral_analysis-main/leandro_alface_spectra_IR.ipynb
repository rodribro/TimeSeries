# %%
#IMPORT PACKAGES
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#IMPORT DATASET
df = pd.read_excel(r'data_lr_IR.xlsx', header=1)
print(df)
# Out:
#     Variety  Date Status       415       445       480       515       555  \
# 0        TA     1   zero  0.076996  0.083650  0.075095  0.102662  0.069392
# 1        TA     1   zero  0.076000  0.086000  0.070000  0.094000  0.040000
# 2        TA     1   zero  0.050517  0.056257  0.047072  0.064294  0.045924
# 3        TA     1   zero  0.081657  0.087574  0.073373  0.097041  0.060355
# 4        TA     1   zero  0.057022  0.064414  0.055966  0.078141  0.059134
# ..      ...   ...    ...       ...       ...       ...       ...       ...
# 308      TA     7  eight  0.048439  0.047901  0.043595  0.053821  0.041981
# 309      TA     7  eight  0.043307  0.043963  0.040682  0.052493  0.045276
# 310      TA     7  eight  0.044357  0.044357  0.040427  0.049972  0.040427
# 311      TA     7  eight  0.040839  0.040287  0.036976  0.045254  0.037528
# 312      TA     7  eight  0.039353  0.040056  0.037245  0.047084  0.040759
#
#           590       630       680       910
# 0    0.164449  0.074144  0.084601  5.336502
# 1    0.096000  0.044000  0.050000  4.854000
# 2    0.111366  0.050517  0.059701  4.862227
# 3    0.176331  0.067456  0.079290  5.829586
# 4    0.136220  0.067582  0.079197  4.857445
# ..        ...       ...       ...       ...
# 308  0.122713  0.039828  0.052207  5.517761
# 309  0.114829  0.042651  0.057087  4.957349
# 310  0.113981  0.037619  0.049972  5.293655
# 311  0.099890  0.034216  0.045806  5.012141
# 312  0.103303  0.037245  0.049895  4.954322
#
# [313 rows x 12 columns]

# %%
# Filter rows where Variety is 'TA'

ta = df[df['Variety'] == 'TA']
#ta = ta[ta['Date'] == 1]

tb = df[df['Variety'] == 'TB']
#tb = tb[tb['Date'] == 1]

print(ta)
# Out:
#     Variety  Date Status       415       445       480       515       555  \
# 0        TA     1   zero  0.076996  0.083650  0.075095  0.102662  0.069392
# 1        TA     1   zero  0.076000  0.086000  0.070000  0.094000  0.040000
# 2        TA     1   zero  0.050517  0.056257  0.047072  0.064294  0.045924
# 3        TA     1   zero  0.081657  0.087574  0.073373  0.097041  0.060355
# 4        TA     1   zero  0.057022  0.064414  0.055966  0.078141  0.059134
# ..      ...   ...    ...       ...       ...       ...       ...       ...
# 308      TA     7  eight  0.048439  0.047901  0.043595  0.053821  0.041981
# 309      TA     7  eight  0.043307  0.043963  0.040682  0.052493  0.045276
# 310      TA     7  eight  0.044357  0.044357  0.040427  0.049972  0.040427
# 311      TA     7  eight  0.040839  0.040287  0.036976  0.045254  0.037528
# 312      TA     7  eight  0.039353  0.040056  0.037245  0.047084  0.040759
#
#           590       630       680       910
# 0    0.164449  0.074144  0.084601  5.336502
# 1    0.096000  0.044000  0.050000  4.854000
# 2    0.111366  0.050517  0.059701  4.862227
# 3    0.176331  0.067456  0.079290  5.829586
# 4    0.136220  0.067582  0.079197  4.857445
# ..        ...       ...       ...       ...
# 308  0.122713  0.039828  0.052207  5.517761
# 309  0.114829  0.042651  0.057087  4.957349
# 310  0.113981  0.037619  0.049972  5.293655
# 311  0.099890  0.034216  0.045806  5.012141
# 312  0.103303  0.037245  0.049895  4.954322
#
# [148 rows x 12 columns]

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming ta is your DataFrame containing the data for 'TA'

# Extracting features from the DataFrame
features = ta.iloc[:, 3:]  # Assuming your features start from the second column


# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(scaled_features)

# Create a DataFrame for the principal components
columns = [f"PC{i+1}" for i in range(principal_components.shape[1])]
principal_df = pd.DataFrame(data=principal_components, columns=columns)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

print("Explained Variance Ratio:")
for i, ratio in enumerate(explained_variance_ratio):
    print(f"PC{i+1}: {ratio:.2f}")

# Optionally, you can also visualize the principal components or perform further analysis
# Out:
# Explained Variance Ratio:
# PC1: 0.78
# PC2: 0.18
# PC3: 0.03
# PC4: 0.00
# PC5: 0.00
# PC6: 0.00
# PC7: 0.00
# PC8: 0.00
# PC9: 0.00

# %%
import matplotlib.pyplot as plt

# Plotting the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(principal_df['PC1'], principal_df['PC2'], alpha=0.8)
plt.title('PCA Scatter Plot')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1', fontsize=20)
plt.ylabel('Principal Component - 2', fontsize=20)
plt.title("Principal Component Analysis of Lettuce Nitrogen Content", fontsize=20)

targets = ['zero', 'two', 'four', 'eight'] 
colors = ['r', 'g', 'b', 'yellow']

for target, color in zip(targets, colors):
    indicesToKeep = df['Status'] == target
    plt.scatter(principal_df.loc[indicesToKeep, 'PC1'], principal_df.loc[indicesToKeep, 'PC2'], c=color, s=50, label=target, alpha=0.8)

plt.legend(prop={'size': 15})
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming tb is your DataFrame containing the data for 'TB'

# Extracting features from the DataFrame
features = tb.iloc[:, 3:]  # Assuming your features start from the second column

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(scaled_features)

# Create a DataFrame for the principal components
columns = [f"PC{i+1}" for i in range(principal_components.shape[1])]
principal_df = pd.DataFrame(data=principal_components, columns=columns)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

print("Explained Variance Ratio:")
for i, ratio in enumerate(explained_variance_ratio):
    print(f"PC{i+1}: {ratio:.2f}")

# Optionally, you can also visualize the principal components or perform further analysis
# Out:
# Explained Variance Ratio:
# PC1: 0.73
# PC2: 0.24
# PC3: 0.01
# PC4: 0.01
# PC5: 0.00
# PC6: 0.00
# PC7: 0.00
# PC8: 0.00
# PC9: 0.00

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1', fontsize=20)
plt.ylabel('Principal Component - 2', fontsize=20)
plt.title("Principal Component Analysis of Lettuce Nitrogen Content", fontsize=20)

targets = ['zero', 'two', 'four', 'eight'] 
colors = ['r', 'g', 'b', 'yellow']

for target, color in zip(targets, colors):
    indicesToKeep = df['Status'] == target
    plt.scatter(principal_df.loc[indicesToKeep, 'PC1'], principal_df.loc[indicesToKeep, 'PC2'], c=color, s=50, label=target, alpha=0.8)

plt.legend(prop={'size': 15})
plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Assuming 'ta' is your DataFrame containing the data for 'TA'

# Extracting features (X) and target (y) from the DataFrame
X = ta.iloc[:, 3:]  # Assuming your features start from the fifth column
y = ta['Status']    # Assuming 'Status' is the target column

# Initialize and fit the LDA model
lda = LinearDiscriminantAnalysis()
lda.fit(X, y)

# Transform the features to the LDA space
X_lda = lda.transform(X)

# Print the explained variance ratio
print("Explained Variance Ratio:")
print(lda.explained_variance_ratio_)

# Optionally, you can perform further analysis or visualization with the transformed features X_lda
# Out:
# Explained Variance Ratio:
# [0.77851169 0.19885603 0.02263228]

# %%
import matplotlib.pyplot as plt

# Define colors for each category
category_colors = {'zero': 'red', 'two': 'blue', 'four': 'green', 'eight': 'orange'}  # Adjust colors as needed

# Plotting the LDA components with colors according to categories
plt.figure(figsize=(8, 6))
for category, color in category_colors.items():
    X_category = X_lda[y == category]
    plt.scatter(X_category[:, 0], X_category[:, 1], color=color, label=category, alpha=0.8)

plt.title('Linear Discriminant Analysis of Lettuce Nitrogen Content - TA variety')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Assuming 'tb' is your DataFrame containing the data for 'TB'

# Extracting features (X) and target (y) from the DataFrame
X = tb.iloc[:, 3:]  # Assuming your features start from the fifth column
y = tb['Status']    # Assuming 'Status' is the target column

# Initialize and fit the LDA model
lda = LinearDiscriminantAnalysis()
lda.fit(X, y)

# Transform the features to the LDA space
X_lda = lda.transform(X)

# Print the explained variance ratio
print("Explained Variance Ratio:")
print(lda.explained_variance_ratio_)

# Optionally, you can perform further analysis or visualization with the transformed features X_lda
# Out:
# Explained Variance Ratio:
# [0.87171723 0.10610701 0.02217576]

# %%
import matplotlib.pyplot as plt

# Define colors for each category
category_colors = {'zero': 'red', 'two': 'blue', 'four': 'green', 'eight': 'orange'}  # Adjust colors as needed

# Plotting the LDA components with colors according to categories
plt.figure(figsize=(8, 6))
for category, color in category_colors.items():
    X_category = X_lda[y == category]
    plt.scatter(X_category[:, 0], X_category[:, 1], color=color, label=category, alpha=0.8)

plt.title('Linear Discriminant Analysis of Lettuce Nitrogen Content - TB variety')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.legend()
plt.grid(True)
plt.show()
